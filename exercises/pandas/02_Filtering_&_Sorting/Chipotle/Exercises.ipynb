# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %%
source_url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"
dataset = pd.read_csv(source_url, sep='\t')

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = dataset

# %%
chipo.head(5)
# Out:
#    order_id  quantity                             item_name  \
# 0         1         1          chips and fresh tomato salsa
# 1         1         1                                  izze
# 2         1         1                      nantucket nectar
# 3         1         1  chips and tomatillogreen chili salsa
# 4         2         2                          chicken bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %% [markdown]
# ### Step _Preprocessing_. Removing duplicate item_name-s
# Some entries in the item_name column differ only by occasional hyphens, such as "Chips and Roasted Chili-Corn Salsa" versus "Chips and Roasted Chili Corn Salsa". I’m standardizing the item_name column by removing hyphens and converting all text to lowercase, in order to merge/remove duplicates. In addition, the item_price parameter is of type str and has to be casted to float64.

# %%
chipo['item_name'] = chipo['item_name'].str.replace(r'-', '', regex=True)
chipo['item_name'] = chipo['item_name'].str.lower()

try:
    chipo['item_price'] = chipo['item_price'].apply(lambda x: float(x[1:]))
except TypeError:
    print("Already changed!")
# Out:
# Already changed!

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
chipo.loc[chipo['item_price'] > 10, 'item_name'].nunique()
# Out:
# 31

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only two columns item_name and item_price

# %%
just_name_and_price = chipo.groupby('item_name', as_index=False)['item_price'].max()
just_name_and_price
# Out:
#                                 item_name  item_price
# 0                       6 pack soft drink       12.98
# 1                           barbacoa bowl       11.75
# 2                        barbacoa burrito       11.75
# 3                   barbacoa crispy tacos       18.50
# 4                     barbacoa salad bowl       11.89
# 5                     barbacoa soft tacos       11.75
# 6                           bottled water       15.00
# 7                                    bowl       22.20
# 8                                 burrito        7.40
# 9                             canned soda        4.36
# 10                      canned soft drink        5.00
# 11                          carnitas bowl       35.25
# 12                       carnitas burrito       18.50
# 13                  carnitas crispy tacos       17.98
# 14                         carnitas salad        8.99
# 15                    carnitas salad bowl       11.89
# ...

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
# Was it already sorted?
just_name_and_price.sort_values(by='item_name')
# Out:
#                                 item_name  item_price
# 0                       6 pack soft drink        6.49
# 1                           barbacoa bowl       11.75
# 2                        barbacoa burrito        8.99
# 3                   barbacoa crispy tacos       11.75
# 4                     barbacoa salad bowl       11.89
# 5                     barbacoa soft tacos        9.25
# 6                           bottled water        1.09
# 7                                    bowl       22.20
# 8                                 burrito        7.40
# 9                             canned soda        2.18
# 10                      canned soft drink        1.25
# 11                          carnitas bowl        8.99
# 12                       carnitas burrito        8.99
# 13                  carnitas crispy tacos        9.25
# 14                         carnitas salad        8.99
# 15                    carnitas salad bowl       11.89
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
price_and_quantity = chipo.groupby('item_name').agg(
    quantity=('quantity', 'sum'),
    price=('item_price', 'max')
).reset_index()

print(price_and_quantity['quantity'].iloc[price_and_quantity['price'].idxmax()])
# Out:
# 130

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
vsb_q = price_and_quantity.loc[
    price_and_quantity['item_name'] == "veggie salad bowl",
    'quantity'
].iloc[0]

print(vsb_q)
# Out:
# 18

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
len(chipo[(chipo['quantity'] >= 2) & (chipo['item_name'] == 'canned soda')])
# Out:
# 20
