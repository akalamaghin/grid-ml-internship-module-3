# %% [markdown]
# # Visualizing the Titanic Disaster

# %% [markdown]
# ### Introduction:
#
# This exercise is based on the titanic Disaster dataset avaiable at [Kaggle](https://www.kaggle.com/c/titanic).
# To know more about the variables check [here](https://www.kaggle.com/c/titanic/data)
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Titanic_Desaster/train.csv)

# %%
source_url = "https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Titanic_Desaster/train.csv"
dataset = pd.read_csv(source_url)

# %% [markdown]
# ### Step 3. Assign it to a variable titanic

# %%
titanic = dataset

# %% [markdown]
# ### Step 4. Set PassengerId as the index

# %%
titanic.set_index('PassengerId')
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# ### Step 5. Create a pie chart presenting the male/female proportion

# %%
labels = ["Male", "Female"]
counts = titanic['Sex'].value_counts()
parts = [
    counts[sex.lower()] / counts.sum() for sex in labels
]

colors = ["blue", "red"]

plt.pie(
    parts,
    colors=colors,
    startangle=90,
    autopct='%1.1f%%',
    textprops={'color':"white", 'fontsize':12}
)

plt.legend(labels, title="Sex", loc="upper right")
plt.title("Gender Proportion")

plt.show()

# %% [markdown]
# ### Step 6. Create a scatterplot with the Fare payed and the Age, differ the plot color by gender

# %%
color_map = {"male": "blue", "female": "red"}
sex_color = lambda x: color_map[x]

plt.scatter(titanic['Age'], titanic['Fare'], alpha=0.4, color=titanic['Sex'].apply(sex_color))

plt.xlabel('Age')
plt.ylabel('Fare')

for sex, color in color_map.items():
    plt.scatter([], [], color=color, label=sex)

plt.legend(title="Sex")
plt.show()

# %% [markdown]
# ### Step 7. How many people survived?

# %%
labels = ['No', 'Yes']
counts = titanic['Survived'].value_counts()
parts = [
    counts[i] / counts.sum() for i in range(2)
]

colors = ["red", "blue"]

plt.pie(
    parts,
    colors=colors,
    startangle=90,
    autopct='%1.1f%%',
    textprops={'color':"white", 'fontsize':12}
)

plt.legend(labels, title="Survived", loc="upper right")
plt.title("Survivors Proportion")

plt.show()

# %% [markdown]
# ### Step 8. Create a histogram with the Fare payed

# %%
titanic['Fare'].plot(kind='hist', bins=20, color="blue")

plt.xlabel('Fare')

plt.show()

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %%
labels = ["First", "Second", "Third"]
counts = titanic['Pclass'].value_counts()
parts = [
    counts[i] / counts.sum() for i in range(1, 4)
]

colors = ["gold", "red", "blue"]

plt.pie(
    parts,
    colors=colors,
    startangle=90,
    autopct='%1.1f%%',
    textprops={'color':"white", 'fontsize':12}
)

plt.legend(labels, title="Class", loc="upper right")
plt.title("Passenger Class Distribution")

plt.show()
